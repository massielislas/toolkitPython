# %%
# %reload_ext autoreload
# %autoreload 2

import os
from toolkit import baseline_learner, utils, manager, arff

data = r"./test/datasets/creditapproval.arff"
my_learner = baseline_learner.BaselineLearner
session = manager.ToolkitSession(arff=data, learner=my_learner, eval_method="training", eval_parameter=None, print_confusion_matrix=False, normalize=False, random_seed=None)
# print(session.arff.data)
# session.arff.data=session.arff.data[:10,:]
# print(session.arff)
# Out:
# Dataset name: ./test/datasets/creditapproval.arff
# Number of instances: 690
# Number of attributes: 16
# Learning algorithm: BaselineLearner
# Evaluation method: training
#
# Calculating accuracy on training set...
# Time to train (in seconds): 0.0019936561584472656
# Training set accuracy: 0.5550724637681159

# %%
import scipy

# %%
import subprocess
import os
print(os.getcwd())
data="./test/datasets/iris.arff"
args = ["L", "baseline", "A", data, "E", "training"]
command = [r"python", "./toolkit/manager.py", *args]
child = subprocess.Popen([*command], shell=False, stdout=subprocess.PIPE, 
                           stderr=subprocess.PIPE)

print(child.communicate(),child.returncode)
# Out:
# /media/taylor/eef4fe97-0587-4acb-b65d-f0ad5ed8d623/taylor/GitHub/realToolkit
# (b'', b'Traceback (most recent call last):\n  File "./toolkit/manager.py", line 3, in <module>\n    from .supervised_learner import SupervisedLearner\nModuleNotFoundError: No module named \'__main__.supervised_learner\'; \'__main__\' is not a package\n') 1

# %%
# %reload_ext autoreload
# %autoreload 2

import os
from toolkit import baseline_learner, utils, manager, arff

data = r"./test/datasets/creditapproval.arff"

d=arff.Arff(data)
e=d.copy()
print(d.data.shape)
e._copy_and_slice_arff(d, 1, slice(2,4,))
print(e)

#d.slice([2:4,4]).data
# Out:
#   File "<ipython-input-75-cc65ef4249ff>", line 15
#     d.slice([2:4,4]).data
#               ^
# SyntaxError: invalid syntax

# %%
import numpy as np
np.nan == np.nan
np.inf == np.inf
# Out:
# @RELATION credit-rating
# @ATTRIBUTE A1 {b, a}
# @ATTRIBUTE A2 CONTINUOUS
# @ATTRIBUTE A3 CONTINUOUS
# @ATTRIBUTE A4 {u, y, l, t}
# @ATTRIBUTE A5 {g, p, gg}
# @ATTRIBUTE A6 {c, d, cc, i, j, k, m, r, q, w, x, e, aa, ff}
# @ATTRIBUTE A7 {v, h, bb, j, n, z, dd, ff, o}
# @ATTRIBUTE A8 CONTINUOUS
# @ATTRIBUTE A9 {t, f}
# @ATTRIBUTE A10 {t, f}
# @ATTRIBUTE A11 CONTINUOUS
# @ATTRIBUTE A12 {t, f}
# @ATTRIBUTE A13 {g, p, s}
# @ATTRIBUTE A14 CONTINUOUS
# @ATTRIBUTE A15 CONTINUOUS
# @ATTRIBUTE class {+, -}
# @DATA
# b, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, r, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, k, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, f, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, k, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, k, v, ?, f, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, k, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, d, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, s, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, d, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, e, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, cc, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, ff, ff, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, q, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, f, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, f, f, ?, t, s, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, d, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, y, p, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, bb, ?, t, f, ?, t, s, ?, ?, -
# b, ?, ?, u, g, d, bb, ?, t, f, ?, t, g, nan, ?, -
# a, ?, ?, u, g, cc, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, y, p, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, y, p, aa, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, k, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, ff, ff, ?, t, t, ?, f, g, ?, ?, -
# a, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# a, nan, ?, u, g, d, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, c, bb, ?, t, f, ?, t, s, ?, ?, -
# b, nan, ?, u, g, d, v, ?, t, f, ?, t, s, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, j, j, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, nan, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, i, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, nan, ?, u, g, c, bb, ?, t, f, ?, t, s, ?, ?, -
# a, ?, ?, y, p, q, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, i, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, e, z, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, f, ?, f, s, ?, ?, -
# a, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, x, h, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, -
# a, ?, ?, y, p, ff, ff, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, k, bb, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, e, z, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, e, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, aa, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, j, ff, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, bb, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, j, j, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, x, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, e, z, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, k, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, m, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, e, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, d, v, ?, f, f, ?, t, g, ?, ?, +
# a, ?, ?, y, p, aa, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, k, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, k, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, s, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, t, ?, f, s, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, aa, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, i, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, i, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, c, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, aa, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, nan, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
#  ['a', '?', '?']
# @RELATION credit-rating
# @ATTRIBUTE A1 {b, a}
# @ATTRIBUTE A2 CONTINUOUS
# @ATTRIBUTE A3 CONTINUOUS
# @ATTRIBUTE A4 {u, y, l, t}
# @ATTRIBUTE A5 {g, p, gg}
# @ATTRIBUTE A6 {c, d, cc, i, j, k, m, r, q, w, x, e, aa, ff}
# @ATTRIBUTE A7 {v, h, bb, j, n, z, dd, ff, o}
# @ATTRIBUTE A8 CONTINUOUS
# @ATTRIBUTE A9 {t, f}
# @ATTRIBUTE A10 {t, f}
# @ATTRIBUTE A11 CONTINUOUS
# @ATTRIBUTE A12 {t, f}
# @ATTRIBUTE A13 {g, p, s}
# @ATTRIBUTE A14 CONTINUOUS
# @ATTRIBUTE A15 CONTINUOUS
# @ATTRIBUTE class {+, -}
# @DATA
# b, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, r, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, k, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, f, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, k, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, k, v, ?, f, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, k, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, d, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, s, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, d, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, e, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, cc, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, ff, ff, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, q, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, f, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, f, f, ?, t, s, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, d, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, y, p, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, bb, ?, t, f, ?, t, s, ?, ?, -
# b, ?, ?, u, g, d, bb, ?, t, f, ?, t, g, nan, ?, -
# a, ?, ?, u, g, cc, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, y, p, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, y, p, aa, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, k, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, ff, ff, ?, t, t, ?, f, g, ?, ?, -
# a, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# a, nan, ?, u, g, d, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, c, bb, ?, t, f, ?, t, s, ?, ?, -
# b, nan, ?, u, g, d, v, ?, t, f, ?, t, s, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, j, j, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, nan, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, i, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, nan, ?, u, g, c, bb, ?, t, f, ?, t, s, ?, ?, -
# a, ?, ?, y, p, q, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, i, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, e, z, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, f, ?, f, s, ?, ?, -
# a, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, x, h, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, -
# a, ?, ?, y, p, ff, ff, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, k, bb, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, e, z, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, e, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, aa, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, j, ff, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, bb, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, j, j, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, x, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, e, z, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, k, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, m, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, e, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, d, v, ?, f, f, ?, t, g, ?, ?, +
# a, ?, ?, y, p, aa, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, k, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, k, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, s, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, t, ?, f, s, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, aa, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, i, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, i, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, c, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, aa, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, nan, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
#  ['a', '?', '?', '?']
# @RELATION credit-rating
# @ATTRIBUTE A1 {b, a}
# @ATTRIBUTE A2 CONTINUOUS
# @ATTRIBUTE A3 CONTINUOUS
# @ATTRIBUTE A4 {u, y, l, t}
# @ATTRIBUTE A5 {g, p, gg}
# @ATTRIBUTE A6 {c, d, cc, i, j, k, m, r, q, w, x, e, aa, ff}
# @ATTRIBUTE A7 {v, h, bb, j, n, z, dd, ff, o}
# @ATTRIBUTE A8 CONTINUOUS
# @ATTRIBUTE A9 {t, f}
# @ATTRIBUTE A10 {t, f}
# @ATTRIBUTE A11 CONTINUOUS
# @ATTRIBUTE A12 {t, f}
# @ATTRIBUTE A13 {g, p, s}
# @ATTRIBUTE A14 CONTINUOUS
# @ATTRIBUTE A15 CONTINUOUS
# @ATTRIBUTE class {+, -}
# @DATA
# b, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, r, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, k, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, f, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, k, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, k, v, ?, f, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, k, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, d, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, s, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, d, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, e, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, cc, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, ff, ff, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, q, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, f, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, f, f, ?, t, s, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, d, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, y, p, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, bb, ?, t, f, ?, t, s, ?, ?, -
# b, ?, ?, u, g, d, bb, ?, t, f, ?, t, g, nan, ?, -
# a, ?, ?, u, g, cc, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, y, p, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, y, p, aa, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, k, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, ff, ff, ?, t, t, ?, f, g, ?, ?, -
# a, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# a, nan, ?, u, g, d, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, c, bb, ?, t, f, ?, t, s, ?, ?, -
# b, nan, ?, u, g, d, v, ?, t, f, ?, t, s, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, j, j, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, nan, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, i, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, nan, ?, u, g, c, bb, ?, t, f, ?, t, s, ?, ?, -
# a, ?, ?, y, p, q, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, i, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, e, z, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, f, ?, f, s, ?, ?, -
# a, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, x, h, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, -
# a, ?, ?, y, p, ff, ff, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, k, bb, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, e, z, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, e, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, aa, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, j, ff, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, bb, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, j, j, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, x, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, e, z, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, k, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, m, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, e, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, d, v, ?, f, f, ?, t, g, ?, ?, +
# a, ?, ?, y, p, aa, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, k, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, k, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, s, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, t, ?, f, s, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, aa, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, i, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, i, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, c, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, aa, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, nan, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
#  ['a', '?', '?', '?', '?']
# @RELATION credit-rating
# @ATTRIBUTE A1 {b, a}
# @ATTRIBUTE A2 CONTINUOUS
# @ATTRIBUTE A3 CONTINUOUS
# @ATTRIBUTE A4 {u, y, l, t}
# @ATTRIBUTE A5 {g, p, gg}
# @ATTRIBUTE A6 {c, d, cc, i, j, k, m, r, q, w, x, e, aa, ff}
# @ATTRIBUTE A7 {v, h, bb, j, n, z, dd, ff, o}
# @ATTRIBUTE A8 CONTINUOUS
# @ATTRIBUTE A9 {t, f}
# @ATTRIBUTE A10 {t, f}
# @ATTRIBUTE A11 CONTINUOUS
# @ATTRIBUTE A12 {t, f}
# @ATTRIBUTE A13 {g, p, s}
# @ATTRIBUTE A14 CONTINUOUS
# @ATTRIBUTE A15 CONTINUOUS
# @ATTRIBUTE class {+, -}
# @DATA
# b, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, r, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, k, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, f, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, k, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, k, v, ?, f, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, k, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, d, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, s, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, d, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, e, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, cc, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, ff, ff, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, q, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, f, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, f, f, ?, t, s, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, d, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, y, p, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, bb, ?, t, f, ?, t, s, ?, ?, -
# b, ?, ?, u, g, d, bb, ?, t, f, ?, t, g, nan, ?, -
# a, ?, ?, u, g, cc, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, y, p, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, y, p, aa, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, k, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, ff, ff, ?, t, t, ?, f, g, ?, ?, -
# a, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# a, nan, ?, u, g, d, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, c, bb, ?, t, f, ?, t, s, ?, ?, -
# b, nan, ?, u, g, d, v, ?, t, f, ?, t, s, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, j, j, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, nan, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, i, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, nan, ?, u, g, c, bb, ?, t, f, ?, t, s, ?, ?, -
# a, ?, ?, y, p, q, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, i, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, e, z, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, f, ?, f, s, ?, ?, -
# a, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, x, h, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, -
# a, ?, ?, y, p, ff, ff, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, k, bb, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, e, z, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, e, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, aa, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, j, ff, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, bb, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, j, j, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, x, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, e, z, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, k, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, m, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, e, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, d, v, ?, f, f, ?, t, g, ?, ?, +
# a, ?, ?, y, p, aa, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, k, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, k, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, s, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, t, ?, f, s, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, aa, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, i, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, i, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, c, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, aa, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, nan, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
#  ['a', '?', '?', '?', '?', '?']
# @RELATION credit-rating
# @ATTRIBUTE A1 {b, a}
# @ATTRIBUTE A2 CONTINUOUS
# @ATTRIBUTE A3 CONTINUOUS
# @ATTRIBUTE A4 {u, y, l, t}
# @ATTRIBUTE A5 {g, p, gg}
# @ATTRIBUTE A6 {c, d, cc, i, j, k, m, r, q, w, x, e, aa, ff}
# @ATTRIBUTE A7 {v, h, bb, j, n, z, dd, ff, o}
# @ATTRIBUTE A8 CONTINUOUS
# @ATTRIBUTE A9 {t, f}
# @ATTRIBUTE A10 {t, f}
# @ATTRIBUTE A11 CONTINUOUS
# @ATTRIBUTE A12 {t, f}
# @ATTRIBUTE A13 {g, p, s}
# @ATTRIBUTE A14 CONTINUOUS
# @ATTRIBUTE A15 CONTINUOUS
# @ATTRIBUTE class {+, -}
# @DATA
# b, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, r, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, k, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, f, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, k, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, k, v, ?, f, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, k, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, d, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, s, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, d, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, e, v, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, cc, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, ff, ff, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, y, p, q, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, f, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, i, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, f, f, ?, t, s, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, d, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, y, p, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, bb, ?, t, f, ?, t, s, ?, ?, -
# b, ?, ?, u, g, d, bb, ?, t, f, ?, t, g, nan, ?, -
# a, ?, ?, u, g, cc, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, y, p, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, y, p, aa, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, k, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, ff, ff, ?, t, t, ?, f, g, ?, ?, -
# a, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, -
# a, nan, ?, u, g, d, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, c, bb, ?, t, f, ?, t, s, ?, ?, -
# b, nan, ?, u, g, d, v, ?, t, f, ?, t, s, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, j, j, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, nan, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, i, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, nan, ?, u, g, c, bb, ?, t, f, ?, t, s, ?, ?, -
# a, ?, ?, y, p, q, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, i, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, e, z, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, f, ?, f, s, ?, ?, -
# a, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, x, h, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, -
# a, ?, ?, y, p, ff, ff, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, k, bb, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, h, ?, t, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, bb, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, e, z, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, e, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# ...
# b, ?, ?, u, g, q, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, cc, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, p, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, w, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, e, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, ff, ff, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, cc, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, ff, ff, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, ff, ff, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, ff, ff, ?, f, t, ?, f, g, ?, ?, -
# a, ?, ?, u, g, ff, ff, ?, f, f, ?, t, s, ?, ?, -
# a, ?, ?, u, g, ff, ff, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, f, t, ?, f, s, ?, ?, -
# b, ?, ?, u, g, ff, ff, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, y, p, m, v, ?, f, f, ?, t, s, ?, ?, -
# b, ?, ?, u, g, k, v, ?, f, f, ?, t, g, ?, ?, -
# a, ?, ?, y, p, j, ff, ?, f, f, ?, f, g, ?, ?, -
# a, nan, ?, u, g, ff, ff, ?, f, f, ?, f, g, nan, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, ff, ff, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, ff, ff, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, nan, ?, y, p, i, bb, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, f, f, ?, f, g, ?, ?, -
# ?, ?, ?, u, g, w, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, d, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, ?, ?, ?, ?, ?, f, f, ?, f, p, nan, ?, -
# b, ?, ?, y, p, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, i, bb, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, f, f, ?, t, g, ?, ?, -
# a, ?, ?, y, p, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, m, v, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, ff, ff, ?, f, t, ?, f, g, ?, ?, -
# a, ?, ?, u, g, j, j, ?, f, t, ?, f, g, ?, ?, -
# a, ?, ?, u, g, m, v, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, w, h, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, i, h, ?, f, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, k, h, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, i, h, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, i, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, i, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, d, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, i, h, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, i, h, ?, f, f, ?, t, s, ?, ?, -
# b, ?, ?, u, g, i, v, ?, f, f, ?, f, g, ?, ?, -
# ?, ?, ?, y, p, ?, ?, ?, f, f, ?, f, s, ?, ?, -
# a, ?, ?, u, g, i, v, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, k, v, ?, f, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, aa, v, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, c, v, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, m, v, ?, f, f, ?, f, s, ?, ?, -
# b, ?, ?, y, p, ff, ff, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, y, p, k, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, ff, ff, ?, f, f, ?, t, g, ?, ?, -
# ?, ?, ?, u, g, q, v, ?, f, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, y, p, c, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, nan, ?, u, g, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, ff, ff, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, j, j, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, e, dd, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, c, h, ?, t, f, ?, f, g, ?, ?, +
# b, nan, ?, u, g, x, v, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, t, g, ?, ?, +
# ?, ?, ?, u, g, k, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, e, dd, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, t, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, i, bb, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, k, h, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, -
# a, ?, ?, u, g, c, h, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, aa, h, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, i, bb, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, ff, ff, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, y, p, ff, ff, ?, t, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, ff, ff, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, x, h, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, w, bb, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, ?, ?, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, cc, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, i, bb, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, k, h, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, i, bb, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, d, v, ?, t, f, ?, f, s, ?, ?, -
# b, ?, ?, y, p, w, v, ?, t, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, d, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, f, ?, f, s, ?, ?, +
# b, ?, ?, u, g, e, z, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, i, bb, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, r, n, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# a, ?, ?, y, p, x, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, q, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, q, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, h, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, x, h, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, y, p, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, d, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, y, p, x, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, ff, ff, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, c, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, e, v, ?, f, t, ?, f, s, ?, ?, +
# b, ?, ?, u, g, m, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, y, p, w, h, ?, t, f, ?, t, g, ?, ?, +
# a, ?, ?, y, p, e, z, ?, t, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, ff, ff, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, y, p, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, u, g, cc, v, ?, t, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, h, ?, t, t, ?, t, g, ?, ?, +
# b, ?, ?, ?, ?, ?, ?, ?, f, f, ?, f, p, nan, ?, +
# b, ?, ?, u, g, w, v, ?, f, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, k, v, ?, t, f, ?, t, g, ?, ?, +
# b, ?, ?, u, g, c, bb, ?, t, f, ?, f, g, ?, ?, +
# a, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, aa, v, ?, t, t, ?, f, g, ?, ?, +
# ?, ?, ?, u, g, q, v, ?, f, t, ?, f, g, ?, ?, +
# b, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +
# a, ?, ?, u, g, k, v, ?, t, t, ?, f, g, ?, ?, +
# ?, ?, ?, y, p, ?, ?, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, k, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, q, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, h, ?, t, f, ?, f, g, ?, ?, -
# a, ?, ?, y, p, k, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, +
# b, ?, ?, u, g, k, v, ?, f, f, ?, t, g, ?, ?, -
# b, nan, ?, y, p, d, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, x, bb, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, k, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, q, h, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, bb, ?, f, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, h, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, i, v, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, ff, ff, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, m, v, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, t, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, i, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, j, ?, f, f, ?, t, s, ?, ?, +
# a, ?, ?, ?, ?, ?, ?, ?, f, f, ?, f, p, nan, ?, +
# b, ?, ?, u, g, q, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, cc, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, s, ?, ?, -
# b, ?, ?, y, p, i, bb, ?, f, f, ?, t, g, nan, ?, -
# b, ?, ?, u, g, ff, ff, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, d, h, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, w, v, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, f, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, m, h, ?, f, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, ff, ff, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, k, ff, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, w, v, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, c, n, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, y, p, m, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, k, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, i, bb, ?, f, f, ?, t, g, ?, ?, -
# ?, ?, ?, y, p, cc, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, aa, v, ?, f, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, aa, h, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, y, p, w, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, cc, v, ?, f, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, u, g, k, h, ?, f, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, ff, ff, ?, f, t, ?, f, g, ?, ?, -
# b, ?, ?, u, g, i, bb, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, f, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, i, v, ?, f, f, ?, t, s, ?, ?, -
# b, ?, ?, u, g, i, v, ?, t, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, q, v, ?, f, t, ?, t, g, ?, ?, -
# a, ?, ?, y, p, ff, ff, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, h, ?, f, t, ?, t, g, ?, ?, -
# a, ?, ?, u, g, aa, v, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, aa, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, w, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, cc, v, ?, f, f, ?, t, g, ?, ?, -
# b, ?, ?, y, p, w, v, ?, f, f, ?, f, s, ?, ?, -
# b, ?, ?, y, p, m, v, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, f, f, ?, t, g, ?, ?, -
# a, ?, ?, u, g, c, v, ?, f, t, ?, t, g, ?, ?, -
# b, ?, ?, u, g, d, h, ?, f, f, ?, t, s, ?, ?, -
# b, ?, ?, y, p, ff, ff, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, w, v, ?, f, f, ?, f, g, ?, ?, -
# b, ?, ?, u, g, cc, v, ?, f, f, ?, f, g, ?, ?, -
# a, ?, ?, u, g, aa, v, ?, f, f, ?, t, g, ?, ?, -
#  []
# '@RELATION credit-rating\n@ATTRIBUTE A1 {b, a}\n@ATTRIBUTE A2 CONTINUOUS\n@ATTRIBUTE A3 CONTINUOUS\n@ATTRIBUTE A4 {u, y, l, t}\n@ATTRIBUTE A5 {g, p, gg}\n@ATTRIBUTE A6 {c, d, cc, i, j, k, m, r, q, w, x, e, aa, ff}\n@ATTRIBUTE A7 {v, h, bb, j, n, z, dd, ff, o}\n@ATTRIBUTE A8 CONTINUOUS\n@ATTRIBUTE A9 {t, f}\n@ATTRIBUTE A10 {t, f}\n@ATTRIBUTE A11 CONTINUOUS\n@ATTRIBUTE A12 {t, f}\n@ATTRIBUTE A13 {g, p, s}\n@ATTRIBUTE A14 CONTINUOUS\n@ATTRIBUTE A15 CONTINUOUS\n@ATTRIBUTE class {+, -}\n@DATA\nb, ?, ?, u, g, w, v, ?, t, t, ?, f, g, ?, ?, +\na, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +\na, ?, ?, u, g, q, h, ?, t, f, ?, f, g, ?, ?, +\nb, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, w, v, ?, t, f, ?, f, s, ?, ?, +\nb, ?, ?, u, g, m, v, ?, t, f, ?, t, g, ?, ?, +\nb, ?, ?, u, g, r, h, ?, t, f, ?, t, g, ?, ?, +\na, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +\nb, ?, ?, y, p, k, h, ?, t, f, ?, f, g, ?, ?, +\nb, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +\nb, ?, ?, u, g, c, h, ?, f, f, ?, t, g, ?, ?, +\nb, ?, ?, u, g, c, h, ?, t, f, ?, f, g, ?, ?, +\na, ?, ?, u, g, k, v, ?, t, f, ?, t, g, ?, ?, +\nb, ?, ?, u, g, k, v, ?, f, f, ?, f, g, ?, ?, +\na, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, y, p, k, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +\na, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, d, h, ?, t, f, ?, t, g, ?, ?, +\na, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, c, v, ?, t, f, ?, f, s, ?, ?, +\na, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +\na, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +\na, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +\na, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +\na, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, d, bb, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, e, h, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, aa, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, x, h, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, i, bb, ?, t, t, ?, t, g, ?, ?, +\na, ?, ?, u, g, e, v, ?, t, f, ?, t, g, ?, ?, +\na, ?, ?, u, g, q, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, cc, h, ?, t, t, ?, t, g, ?, ?, +\na, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, y, p, cc, v, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, ff, ff, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, c, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, c, h, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, w, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, y, p, c, v, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, c, h, ?, t, t, ?, t, g, ?, ?, +\na, ?, ?, y, p, q, h, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, cc, h, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, i, bb, ?, f, f, ?, f, g, ?, ?, +\nb, ?, ?, u, g, c, v, ?, f, f, ?, f, g, ?, ?, +\na, ?, ?, u, g, c, h, ?, t, f, ?, t, g, ?, ?, +\nb, ?, ?, u, g, q, v, ?, t, f, ?, t, g, ?, ?, +\nb, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +\nb, ?, ?, u, g, w, v, ?, t, f, ?, t, g, ?, ?, +\nb, ?, ?, u, g, cc, h, ?, t, f, ?, t, g, ?, ?, +\nb, ?, ?, y, p, w, v, ?, t, f, ?, t, g, ?, ?, +\nb, ?, ?, u, g, cc, v, ?, t, f, ?, f, g, ?, ?, +\nb, ?, ?, u, g, i, h, ?, t, f, ?, t, g, ?, ?, +\nb, ?, ?, u, g, x, h, ?, f, f, ?, t, s, ?, ?, +\nb, ?, ?, u, g, q, h, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, m, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, d, v, ?, t, t, ?, f, g, ?, ?, +\na, ?, ?, y, p, q, v, ?, t, t, ?, t, g, ?, ?, +\na, ?, ?, u, g, q, v, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, cc, v, ?, t, t, ?, t, g, ?, ?, +\na, ?, ?, u, g, c, v, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, m, v, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, w, h, ?, t, t, ?, f, g, ?, ?, +\nb, ?, ?, u, g, x, h, ?, t, t, ?, t, g, ?, ?, +\nb, ?, ?, u, g, e, bb, ?, t, f, ?, t, s, ?, ?, -\nb, ?, ?, u, g, d, bb, ?, t, f, ?, t, g, nan, ?, -\na, ?, ?, u, g, cc, v, ?, t, f, ...

# %%
print(x)
x[1:5,(3,5,14)]
# Out:
# [[0.000e+00 3.083e+01 0.000e+00 ... 2.020e+02 0.000e+00 0.000e+00]
#  [1.000e+00 5.867e+01 4.460e+00 ... 4.300e+01 5.600e+02 0.000e+00]
#  [1.000e+00 2.450e+01 5.000e-01 ... 2.800e+02 8.240e+02 0.000e+00]
#  ...
#  [1.000e+00 2.525e+01 1.350e+01 ... 2.000e+02 1.000e+00 1.000e+00]
#  [0.000e+00 1.792e+01 2.050e-01 ... 2.800e+02 7.500e+02 1.000e+00]
#  [0.000e+00 3.500e+01 3.375e+00 ... 0.000e+00 0.000e+00 1.000e+00]]
# array([[  0.,   8., 560.],
#        [  0.,   8., 824.],
#        [  0.,   9.,   3.],
#        [  0.,   9.,   0.]])

# %%
# %reload_ext autoreload
# %autoreload 2
f = e.create_subset_arff([1,2,3,9],slice(0,3))
# Out:
# HERE <class 'toolkit.arff.Arff'>
# HE
# THERE <class 'toolkit.arff.Arff'>

# %%
e[0:None,:].shape==e.data.shape
# Out:
# True

# %%
print(f)
# Out:
# @RELATION Untitled_subset
# @ATTRIBUTE 0 CONTINUOUS
# @ATTRIBUTE 1 CONTINUOUS
# @ATTRIBUTE 2 CONTINUOUS
# @DATA
# 1.0, 58.67, 4.46
# 1.0, 24.5, 0.5
# 0.0, 27.83, 1.54
# 0.0, 42.5, 4.915

# %%
isinstance(f,type(e))
# Out:
# True

# %%
import numpy as np
col_idx = slice(8,-1)
print(e.data[col_idx])
#col_idx = [3,4,7,9]
requested_columns = np.r_(e.data[col_idx])
print(requested_columns)
print(col_idx.stop)
# Out:
# [[  0.    54.42   0.5    1.     1.     5.     1.     3.96   0.     1.
#     0.     1.     0.   180.   314.     0.  ]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-215-0538818226dc> in <module>
#       3 print(e.data[col_idx])
#       4 #col_idx = [3,4,7,9]
# ----> 5 requested_columns = np.r_(e.data[col_idx])
#       6 print(requested_columns)
#       7 print(col_idx.stop)
#
# TypeError: 'RClass' object is not callable

# %%
isinstance(r"THIS/that/theother.arff", str)
# Out:
# True

# %%
class klf:

    def m(self):
        print(type(self))

m = klf()
print(type(m) is klf)

print(type(m))
m.m()
# Out:
# True
# <class '__main__.klf'>
# <class '__main__.klf'>

# %%
import os
os.listdir()
# Out:
# ['.coverage',
#  '.git',
#  'venv',
#  'tox.ini',
#  'toolkit',
#  'setup.py',
#  'venv2.7',
#  'toolkit.egg-info',
#  'README.md',
#  'datasets',
#  'Testing.ipynb',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '.idea',
#  '.tox',
#  'run.py',
#  'implemented',
#  'test']

# %%
os.path.dirname("/this")
# Out:
# '/'
